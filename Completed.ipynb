# %% [markdown]
# <a href="https://colab.research.google.com/github/shashank2007-ai/carbook/blob/main/Completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print('                                  WELCOME TO CAR BOOKING/SELLING/RENTING SYSTEM')
print('          _______            -           __                                ______--------___   ')
print('         //  ||\ \         --          ~( @\   \                          /|             / |   ')
print('   _____//___||_\ \___    ---   _________]_[__/_>________      o___________|_\__________/__|   ')
print('  }  _          _    \         /  ____ \ <>     |  ____  \    ]|___     |  |=   ||  =|___  |   ')
print('  |_/ \________/ \___|        =\_/ __ \_\_______|_/ __ \__D   //   \\    |  |____||_///   \\|  ')
print(' ___\_/________\_/______  ________(__)_____________(__)____   |  X  |\--------------/|  X  |\   ')
print('                                                               \___/                  \___/   ')
print("WELCOME TO OUR NO.1 CAR RESALE AND BOOKING SITE!! ENJOY 10% OFF ON YOUR FIRST REGISTRATION")
U_name=input("Enter your name:")
res=input("Enter your state of residence:")
ph_no=int(input("Enter your phone number:"))
def otttp():
  otp=random.randint(1000,9999)
  print("your OTP is :",otp)
  ottp=int(input("Enter the OTP sent on your mobile:"))
  if otp==ottp:
    print("OTP verified")
  else:
    print("incorrect otp")
    otttp()
otttp()
def modef():
  list_mode=('Buy','Sell','Rent')
  print('Choose mode\nBuy\t\tSell\t\tRent')
  mod = input('')
  if mod not in list_mode:
    print('Enter valid option')
    mod = modef()
  return mod
mode = modef()

def car_choose():
  print('Enter Car Class\nSUV\t\tSedan\t\tSports\t\tLuxury')
  def Cartype():
    a = input('')
    return a
  cartype = Cartype()
  n='to buy'
  dict_suv={1:'Audi Q3',2:'BMW X5',3:'Tata Safari',4:'Mahindra Thar',5:'Ford Ecosport',6:'Land Rover',7:'Mercedes G Class',8:'Kia Sonet',9:'Toyota Fortuner',10:'Nissan Magnite'}
  dict_sedan={1:'Audi A4',2:'Nissan Altima',3:'Mercedes Benz',4:'Skoda Slavia',5:'Swift Dezire',6:'BMW M340I',7:'Hyundai Aura',8:'Volvo S90',9:'Toyota Camry',10:'Jaguae XF',}
  dict_sports={1:'Chevolet Camaro',2:'Chevolet Corvette',3:'Ford Mustang',4:'Mclaren Artura',5:'Porche 911',6:'Pagani Zonda R',7:'Toyota Supra',8:'Audi TT',9:"Mazda Furai",10:"Nissan GTR"}
  dict_lux={1:'Lamborghini Sian',2:'Rolls Royce Wraith',3:'Pagani Huyara',4:'Apollo Intensa',5:'Bugatti Bolide',6:'Bugatti Centodieci',7:'Lamborghini Aventedor',8:'Lamborghini Terzo',9:'Ferrari Laferrari',10:'Mclaren Solis'}
  def SUV():
    print('choose car to see more details (use option no or Name of car)')
    print('available Cars:-\n 1. Audi Q3 \t 2. BMW X5 \t\t 3. Tata Safari     4. Mahindra Thar \t 5. Ford Ecosport \n 6. Land rover \t 7. Mercedes G Class \t 8. Kia Sonet \t    9. Toyota Fortuner \t 10. Nissan Magnite')
    Suv_option=input('')
    if Suv_option in str(dict_suv.keys()):
      ficar = dict_suv[int(Suv_option)]
    elif Suv_option in dict_suv.values():
      ficar = Suv_option
    else:
      print('Enter Valid Car')
      SUV()
    return ficar
  def Sedan():
    print('choose car to see more details (use option no or Name of car)')
    print('available Cars:-\n 1. Audi A4 \t 2. Nissan Altima \t 3. Mercedes Benz \t 4. Skoda Slavia \t5. Swift Dezire \n 6. BMW M340I \t 7. Hyundai Aura \t 8. Volvo S90 \t\t 9. Toyota Camry \t10. Jaguar XF')
    Sedan_option=input('')
    if Sedan_option in str(dict_sedan.keys()):
      ficar = dict_sedan[int(Sedan_option)]
    elif Sedan_option in dict_sedan.values():
      ficar = Sedan_option
    else:
      print('Enter Valid Car')
      Sedan()
    return ficar
  def Sports():
    print("choose car to see more details (use option no or Name of car)")
    print("available cars:-\n1. Chevolet Camaro \t 2. Chevolet Corvette \t 3. Ford Mustang\t 4. Mclaren Artura\t 5. Porche 911\n6. Pagani Zonda R \t 7. Toyota Supra\t 8. Audi TT\t\t 9. Mazda Furai\t\t 10. Nissan GTR")
    Sports_option=input('')
    if Sports_option in str(dict_sports.keys()):
      ficar = dict_sports[int(Sports_option)]
    elif Sports_option in dict_sports.values():
      ficar = Sports_option
    else:
      print('Enter Valid Car')
      Sports()
    return ficar
  def Lux():
    print('choose car to see more details (use option no or Name of car)')
    print('available Cars:-\n 1. Lamborghini Sian \t 2. Rolls Royce Wraith \t     3. Pagani Huyara \t\t4. Apollo Intensa\t 5. Bugatti Bolide \n 6. Bugatti Centodieci \t 7. Lamborghini Aventedor    8. Lamborghini Terzo\t9. Ferrari Laferrari \t 10. Mclaren Solis')
    Lux_option=input('')
    if Lux_option in str(dict_lux.keys()):
      ficar = dict_lux[int(Lux_option)]
    elif Lux_option in dict_lux.values():
      ficar = Lux_option
    else:
      print('Enter Valid Car')
      Lux()
    return ficar
  if cartype == 'SUV' or cartype == 'suv' or cartype == 'Suv':
    fcar = SUV()
    ctype = 'suv'
  elif cartype == 'Sedan' or cartype == 'sedan' or cartype == 'SEDAN':
    fcar = Sedan()
    ctype = 'sedan'
  elif cartype == 'Sports' or cartype == 'sports' or cartype == 'SPORTS':
    fcar = Sports()
    ctype = 'sports'
  elif cartype == 'Luxury' or cartype == 'luxury' or cartype == 'LUXURY':
    fcar = Lux()
    ctype = 'luxury'
  else:
    print('Enter Valid Option')
    car_choose()
  return fcar , ctype
finalcar , cart = car_choose()
if cart == 'suv':
  pricer = random.randint(300000,500000)
elif cart == 'sedan':
  pricer = random.randint(400000,1000000)
elif cart == 'sports':
  pricer = random.randint(2500000,4000000)
elif cart == 'luxury':
  pricer = random.randint(4000000,8000000)
def finalbuyui():
  print('Car choosen: \t',finalcar)
  print('Total Price: \t ₹',(pricer))
  residence = input('Enter resident address: ')
  otttp()
  print('Your choosen car has been booked, pls visit nearest car showroom, payment will be done on spot, Thank You')
def finalsellui():
  print('Pls enter your car name')
  prices = random.randint(100000, 500000)
  print('The price offered for your car is ', prices , 'Pls visit nearest showroom to continue. After inspection the payment, which may fluctuate, will be done by net banking')
def finalrentui():
  print('Car choosen: \t',finalcar)
  time = int(input('Enter time to rent in hours: '))
  fprice = (pricer // 200) * time
  print('Total Price: \t ₹', fprice )
  residence = input('Enter resident address: ')
  day = input('Enter date for carbooking: ')
  timeday = input('Enter time for arrival of car: ')
  otttp()
  print('Your car has been booked it will arrive at ', timeday , ' on ', day ,' on your registered address: ', residence , '\n Thank You')
if mode == 'Buy':
  finalbuyui()
elif mode == 'Sell':
  finalsellui()
elif mode == 'Rent':
  finalrentui()
# Out:
#                                   WELCOME TO CAR BOOKING/SELLING/RENTING SYSTEM
#           _______            -           __                                ______--------___
#          //  ||\ \         --          ~( @\   \                          /|             / |
#    _____//___||_\ \___    ---   _________]_[__/_>________      o___________|_\__________/__|
#   }  _          _    \         /  ____ \ <>     |  ____  \    ]|___     |  |=   ||  =|___  |
#   |_/ \________/ \___|        =\_/ __ \_\_______|_/ __ \__D   //   \    |  |____||_///   \|
#  ___\_/________\_/______  ________(__)_____________(__)____   |  X  |\--------------/|  X  |\
#                                                                \___/                  \___/
# WELCOME TO OUR NO.1 CAR RESALE AND BOOKING SITE!! ENJOY 10% OFF ON YOUR FIRST REGISTRATION
# Enter your name:
# Enter your state of residence:9
# Enter your phone number:9
# your OTP is : 4777
# Enter the OTP sent on your mobile:4777
# OTP verified
# ...
